# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./water_potability.csv")

# %%
data.sample(5)
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 2067  6.811702  261.389565  15149.489871     7.056107         NaN
# 2606  4.137045  116.338278  17101.951569     8.652210  322.892252
# 728   7.110845  213.886337  25043.532803     6.048437  245.954253
# 2249  4.400509  119.334036  19100.087124    11.753904         NaN
# 3008  9.405875  149.308297  27180.057189     7.867309         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 2067    397.787119       11.993516        66.257649   3.275008           0
# 2606    360.648078        7.848313        70.977001   4.327356           0
# 728     505.735535       16.383140        91.681026   5.712792           1
# 2249    328.399763       14.912109        49.356509   4.010809           0
# 3008    398.806246       17.364706        57.962637   4.033733           0

# %%
data.shape
# Out:
# (3276, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
data.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
data.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(data, test_size=0.2)

# %%
train_data.shape, test_data.shape
# Out:
# ((2620, 10), (656, 10))

# %%
train_data.head()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 1211  6.114332  178.446286  30606.223593     5.568042  260.771026
# 2234  7.345138  202.174463  17032.773734     6.212629  361.440487
# 1513  6.353437  218.549363  18664.844297     6.690394  312.393019
# 2039  5.226895  127.117555   7907.330441     6.761929  335.461842
# 824   6.400256  172.299000  15936.247360     4.935998  340.392930
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 1211    472.255403       16.711471        46.552618   3.680410           1
# 2234    600.295028       17.299740        89.077865   4.297995           0
# 1513    503.414897       15.422459        94.386932   3.861109           1
# 2039    475.332357       12.725010        79.420013   5.138056           1
# 824     435.405610       11.075622        58.365995   4.561494           0

# %%
test_data.head()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 1912  7.760189  206.208834  34250.163925     7.930382  299.131598
# 674   4.931958  164.666769  31155.540218     7.411483  383.782626
# 1492  8.837787  195.827213  11610.207949     7.870062  332.759029
# 190   7.793834  176.866483  18344.680361     7.567677  338.229597
# 3022       NaN  196.051741  21919.470163     6.730277  359.701352
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 1912    347.180780       19.350765        80.621872   4.590528           1
# 674     506.531414       14.980034        69.249229   5.045983           1
# 1492    514.925997       12.291616        87.429078   2.087080           1
# 190     371.216973        9.039042        76.288076   4.172935           0
# 3022    401.731338       14.219303        77.605726   3.954964           0

# %%
def fill_missing_with_median(df):
    for column in df.columns:
        if df[column].isnull().any():
            median_value = df[column].median()
            df[column].fillna(median_value, inplace=True)
    return df

# %%
train_processed_data = fill_missing_with_median(train_data)
test_processed_data = fill_missing_with_median(test_data)

# %%
from sklearn.ensemble import RandomForestClassifier
import pickle

# %%
X_train = train_processed_data.iloc[:, 0:-1].values
y_train = train_processed_data.iloc[:, -1].values

# %%
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
pickle.dump(clf, open("model.pkl", "wb"))

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
model = pickle.load(open("model.pkl", "rb"))

# %%
X_test = test_processed_data.iloc[:, 0:-1].values
y_test = test_processed_data.iloc[:, -1].values

# %%
X_test.shape
# Out:
# (656, 9)

# %%
y_pred = model.predict(X_test)

# %%
y_pred.shape
# Out:
# (656,)

# %%
acc = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1_score = f1_score(y_test, y_pred)

# %%
print("Accuracy: ", acc)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1-Score: ", f1_score)
# Out:
# Accuracy:  0.649390243902439
# Precision:  0.6028368794326241
# Recall:  0.3281853281853282
# F1-Score:  0.425
